# %% [markdown]
# In this notebook I'll explore the data available from sportmonks by using methods from the Sportmonks class. Data we will look to display (if available are the following):
# * leagues
# * seasons
# * fixtures
# * event data (goal, cards)
# * odds data
#
# NB: This notebook uses a season id that won't be available after the trial ends.
#
# NB: Sportmonks only has odds data from 2017/2018 onwards
#
# # Imports

# %%
import pandas as pd
from sportmonks_class import Sportmonks
from sportmonks_config import (
    FIXTURES_EVENT_INCLUDES,
    FIXTURES_ODDS_INCLUDES,
)

# %% [markdown]
# # Instantiate Sportmonks Class

# %%
sm = Sportmonks()

# %% [markdown]
# # Fetch data available from Sportmonks API

# %% [markdown]
# Fetch countries

# %%
countries_df = sm.get_countries()
countries_df.head(3)
# Out:
#    id     name                                         image_path  \
# 0   2   Poland  https://cdn.sportmonks.com/images/countries/pn...
# 1   5   Brazil  https://cdn.sportmonks.com/images/countries/pn...
# 2  11  Germany  https://cdn.sportmonks.com/images/countries/pn...
#
#   extra.continent extra.sub_region extra.world_region extra.fifa extra.iso  \
# 0          Europe   Eastern Europe               EMEA        POL       POL
# 1        Americas    South America               AMER        BRA       BRA
# 2          Europe   Western Europe               EMEA        GER       DEU
#
#   extra.iso2     extra.longitude      extra.latitude  \
# 0         PL   19.37775993347168  52.147850036621094
# 1         BR  -52.97311782836914  -10.81045150756836
# 2         DE  10.382203102111816   51.20246505737305
#
#                                           extra.flag  extra
# 0  <svg xmlns="http://www.w3.org/2000/svg" width=...    NaN
# 1  <svg version="1" xmlns="http://www.w3.org/2000...    NaN
# 2  <svg xmlns="http://www.w3.org/2000/svg" width=...    NaN

# %% [markdown]
# Fetch league data

# %%
leagues_df = sm.get_leagues()
leagues_df.head(3)
# Out:
#    id  active      type  legacy_id  country_id  \
# 0   8    True  domestic         29         462
# 1  72    True  domestic          1          38
# 2  82    True  domestic          4          11
#
#                                            logo_path            name  is_cup  \
# 0  https://cdn.sportmonks.com/images/soccer/leagu...  Premier League   False
# 1  https://cdn.sportmonks.com/images/soccer/leagu...      Eredivisie   False
# 2  https://cdn.sportmonks.com/images/soccer/leagu...      Bundesliga   False
#
#    is_friendly  current_season_id  current_round_id  current_stage_id  \
# 0        False              19734          274675.0        77457864.0
# 1        False              19726          274589.0        77457832.0
# 2        False              19744          274911.0        77457883.0
#
#    live_standings  coverage.predictions  coverage.topscorer_goals  \
# 0            True                  True                      True
# 1            True                  True                      True
# 2            True                  True                      True
#
#    coverage.topscorer_assists  coverage.topscorer_cards
# 0                        True                      True
# 1                        True                      True
# 2                        True                      True

# %% [markdown]
# Fetch seasons

# %%
seasons_json = sm.get_seasons()
seasons_df = pd.DataFrame(seasons_json)

seasons_df.query('league_id == 8').tail(3)
# Out:
#        id       name  league_id  is_current_season  current_round_id  \
# 15  17420  2020/2021          8              False               NaN
# 16  18378  2021/2022          8              False          247621.0
# 17  19734  2022/2023          8               True          274675.0
#
#     current_stage_id                                             stages  \
# 15               NaN  [{'id': 77448322, 'name': 'Regular Season', 't...
# 16        77453700.0  [{'id': 77453700, 'name': 'Regular Season', 't...
# 17        77457864.0  [{'id': 77457864, 'name': 'Regular Season', 't...
#
#                                                rounds
# 15  [{'id': 201963, 'name': 1, 'league_id': 8, 'se...
# 16  [{'id': 247583, 'name': 1, 'league_id': 8, 'se...
# 17  [{'id': 274668, 'name': 1, 'league_id': 8, 'se...

# %% [markdown]
# Set example season_id

# %%
season_id = 18378 # last season's premier league

# %% [markdown]
# Fixtures with events

# %%
fixtures_w_events_json = sm.get_season_fixtures(
    season_id, 
    includes_list = FIXTURES_EVENT_INCLUDES,
    seasons_json=seasons_json
)

# %%
fixtures_w_events_df = pd.DataFrame(fixtures_w_events_json)

fixtures_w_events_df[
    [
        'id',
        'league_id',
        'season_id',
        'localteam_id',
        'visitorteam_id',
        'winner_team_id',
        'scores',
        'time',
        'goals',
        'cards',
        'corners',
        'lineup',
        'bench',
        'stats',
        'events'
    ]
].head(3)
# Out:
#          id  league_id  season_id  localteam_id  visitorteam_id  \
# 0  18138603          8      18378           236              19
# 1  18138608          8      18378            14              71
# 2  18138604          8      18378            27              78
#
#    winner_team_id                                             scores  \
# 0           236.0  {'localteam_score': 2, 'visitorteam_score': 0,...
# 1            14.0  {'localteam_score': 5, 'visitorteam_score': 1,...
# 2            78.0  {'localteam_score': 1, 'visitorteam_score': 2,...
#
#                                                 time  \
# 0  {'status': 'FT', 'starting_at': {'date_time': ...
# 1  {'status': 'FT', 'starting_at': {'date_time': ...
# 2  {'status': 'FT', 'starting_at': {'date_time': ...
#
#                                                goals  \
# 0  [{'id': 18138603001, 'team_id': '236', 'type':...
# 1  [{'id': 18138608001, 'team_id': '14', 'type': ...
# 2  [{'id': 18138604001, 'team_id': '27', 'type': ...
#
#                                                cards  \
# 0                                                 []
# 1  [{'id': 18138608006, 'team_id': '71', 'type': ...
# 2  [{'id': 18138604002, 'team_id': '27', 'type': ...
#
#                                              corners  \
# 0  [{'id': 3406696354, 'team_id': 19, 'fixture_id...
# 1  [{'id': 3412571333, 'team_id': 14, 'fixture_id...
# 2  [{'id': 3415499437, 'team_id': 27, 'fixture_id...
#
#                                               lineup  \
# 0  [{'team_id': 236, 'fixture_id': 18138603, 'pla...
# 1  [{'team_id': 14, 'fixture_id': 18138608, 'play...
# 2  [{'team_id': 27, 'fixture_id': 18138604, 'play...
#
#                                                bench  \
# 0  [{'team_id': 236, 'fixture_id': 18138603, 'pla...
# 1  [{'team_id': 14, 'fixture_id': 18138608, 'play...
# 2  [{'team_id': 27, 'fixture_id': 18138604, 'play...
#
#                                                stats  \
# 0  [{'team_id': 236, 'fixture_id': 18138603, 'sho...
# 1  [{'team_id': 14, 'fixture_id': 18138608, 'shot...
# 2  [{'team_id': 27, 'fixture_id': 18138604, 'shot...
#
#                                               events
# 0  [{'id': 18138603001, 'team_id': '236', 'type':...
# 1  [{'id': 18138608001, 'team_id': '14', 'type': ...
# 2  [{'id': 18138604001, 'team_id': '27', 'type': ...

# %% [markdown]
# Goals data available

# %%
fixtures_w_events_json[3]['goals']
# Out:
# [{'id': 18138605001,
#   'team_id': '18',
#   'type': 'goal',
#   'fixture_id': 18138605,
#   'player_id': 1128,
#   'player_name': 'M. Alonso',
#   'player_assist_id': None,
#   'player_assist_name': None,
#   'minute': 27,
#   'extra_minute': None,
#   'reason': None,
#   'result': '1-0'},
#  {'id': 18138605002,
#   'team_id': '18',
#   'type': 'goal',
#   'fixture_id': 18138605,
#   'player_id': 32438,
#   'player_name': 'C. Pulisic',
#   'player_assist_id': None,
#   'player_assist_name': None,
#   'minute': 40,
#   'extra_minute': None,
#   'reason': None,
#   'result': '2-0'},
#  {'id': 18138605005,
#   'team_id': '18',
#   'type': 'goal',
#   'fixture_id': 18138605,
#   'player_id': 537117,
#   'player_name': 'T. Chalobah',
#   'player_assist_id': 73147,
#   'player_assist_name': 'M. Kovacic',
#   'minute': 58,
#   'extra_minute': None,
#   'reason': None,
#   'result': '3-0'}]

# %% [markdown]
# Cards data available

# %%
fixtures_w_events_json[2]['cards']
# Out:
# [{'id': 18138604002,
#   'team_id': '27',
#   'type': 'yellowcard',
#   'fixture_id': 18138604,
#   'player_id': 1611,
#   'player_name': 'J. Gudmundsson',
#   'minute': 9,
#   'extra_minute': None,
#   'reason': None,
#   'on_pitch': None},
#  {'id': 18138604003,
#   'team_id': '27',
#   'type': 'yellowcard',
#   'fixture_id': 18138604,
#   'player_id': 1639,
#   'player_name': 'J. Tarkowski',
#   'minute': 13,
#   'extra_minute': None,
#   'reason': None,
#   'on_pitch': None},
#  {'id': 18138604004,
#   'team_id': '78',
#   'type': 'yellowcard',
#   'fixture_id': 18138604,
#   'player_id': 95776,
#   'player_name': 'N. Maupay',
#   'minute': 26,
#   'extra_minute': None,
#   'reason': None,
#   'on_pitch': None}]

# %% [markdown]
# Fixtures with odds data

# %%
fixtures_w_odds_json = sm.get_season_fixtures(
    season_id, 
    includes_list = FIXTURES_ODDS_INCLUDES,
    seasons_json=seasons_json
)

# %%
fixtures_w_odds_json[0]['odds'][0]
# Out:
# {'id': 1,
#  'name': '3Way Result',
#  'suspended': False,
#  'bookmaker': [{'id': 2,
#    'name': 'bet365',
#    'odds': [{'label': '1',
#      'value': '3.80',
#      'extra': None,
#      'probability': '26.32%',
#      'dp3': '3.800',
#      'american': 280,
#      'factional': None,
#      'handicap': None,
#      'total': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': 104082057,
#      'last_update': {'date': '2021-08-13 18:44:06.309789',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'label': 'X',
#      'value': '3.25',
#      'extra': None,
#      'probability': '30.77%',
#      'dp3': '3.250',
#      'american': 225,
#      'factional': None,
#      'handicap': None,
#      'total': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': 104082057,
#      'last_update': {'date': '2021-08-13 18:44:06.309808',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'label': '2',
#      'value': '2.05',
#      'extra': None,
#      'probability': '48.78%',
#      'dp3': '2.050',
#      'american': 104,
#      'factional': None,
#      'handicap': None,
#      'total': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': 104082057,
#      'last_update': {'date': '2021-08-13 18:44:06.309819',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 150,
#    'name': 'bwin',
#    'odds': [{'value': '3.80',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '26.32%',
#      'dp3': '3.800',
#      'american': 280,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': '11715276',
#      'last_update': {'date': '2021-08-13 18:45:11.973952',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': '11715276',
#      'last_update': {'date': '2021-08-13 18:45:11.974002',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.05',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '48.78%',
#      'dp3': '2.050',
#      'american': 104,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': '11715276',
#      'last_update': {'date': '2021-08-13 18:45:11.974013',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 271057098,
#    'name': 'NordicBet',
#    'odds': [{'value': '3.85',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.97%',
#      'dp3': '3.850',
#      'american': 285,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.278106',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.35',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '29.85%',
#      'dp3': '3.350',
#      'american': 235,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.278130',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.10',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.62%',
#      'dp3': '2.100',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.278139',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 1,
#    'name': '10Bet',
#    'odds': [{'value': '3.80',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '26.32%',
#      'dp3': '3.800',
#      'american': 280,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.986270',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.986282',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.10',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.62%',
#      'dp3': '2.100',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.986291',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 25679219,
#    'name': 'Marathon',
#    'odds': [{'value': '4.05',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '24.69%',
#      'dp3': '4.050',
#      'american': 305,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.999131',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.999144',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.11',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.39%',
#      'dp3': '2.110',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:11.999152',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 97,
#    'name': 'Unibet',
#    'odds': [{'value': '3.95',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.32%',
#      'dp3': '3.950',
#      'american': 295,
#      'factional': None,
#      'winning': True,
#      'stop': True,
#      'bookmaker_event_id': '1007732386',
#      'last_update': {'date': '2021-08-13 18:57:14.832301',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.35',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '29.85%',
#      'dp3': '3.350',
#      'american': 235,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': '1007732386',
#      'last_update': {'date': '2021-08-13 18:57:14.832328',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.10',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.62%',
#      'dp3': '2.100',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': '1007732386',
#      'last_update': {'date': '2021-08-13 18:57:14.832343',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 114,
#    'name': 'Betsson',
#    'odds': [{'value': '3.85',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.97%',
#      'dp3': '3.850',
#      'american': 285,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.284013',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.35',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '29.85%',
#      'dp3': '3.350',
#      'american': 235,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.284031',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.10',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.62%',
#      'dp3': '2.100',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.284040',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 3,
#    'name': '188Bet',
#    'odds': [{'value': '3.25',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.77%',
#      'dp3': '3.250',
#      'american': 225,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.020234',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.75',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '26.67%',
#      'dp3': '3.750',
#      'american': 275,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.289451',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.13',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '46.95%',
#      'dp3': '2.130',
#      'american': 112,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:59:09.289467',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 70,
#    'name': 'Pncl',
#    'odds': [{'value': '3.97',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.19%',
#      'dp3': '3.970',
#      'american': 297,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:54:08.484971',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.36',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '29.76%',
#      'dp3': '3.360',
#      'american': 236,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:54:08.485012',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.12',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.17%',
#      'dp3': '2.120',
#      'american': 112,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:54:08.485023',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 25679320,
#    'name': 'Sbo',
#    'odds': [{'value': '3.20',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '31.25%',
#      'dp3': '3.200',
#      'american': 220,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.034901',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.16',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '46.3%',
#      'dp3': '2.160',
#      'american': 116,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.034909',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.70',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '27.03%',
#      'dp3': '3.700',
#      'american': 270,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:54:08.495395',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 25679340,
#    'name': '1xbet',
#    'odds': [{'value': '3.34',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '29.94%',
#      'dp3': '3.340',
#      'american': 234,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:54:08.503068',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '4.19',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '23.87%',
#      'dp3': '4.190',
#      'american': 319,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:57:14.838295',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.03',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '49.26%',
#      'dp3': '2.030',
#      'american': 102,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:57:14.838312',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 271057091,
#    'name': 'Sportingbet',
#    'odds': [{'value': '3.80',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '26.32%',
#      'dp3': '3.800',
#      'american': 280,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.046590',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.046602',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.05',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '48.78%',
#      'dp3': '2.050',
#      'american': 104,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.046610',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 271057099,
#    'name': 'ComeOn',
#    'odds': [{'value': '3.65',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '27.4%',
#      'dp3': '3.650',
#      'american': 265,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.052297',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.60',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '27.78%',
#      'dp3': '3.600',
#      'american': 260,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.052310',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '1.95',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '51.28%',
#      'dp3': '1.950',
#      'american': -106,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.052318',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 271057083,
#    'name': 'Bovada',
#    'odds': [{'value': '3.70',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '27.03%',
#      'dp3': '3.700',
#      'american': 270,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.057925',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.70',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '27.03%',
#      'dp3': '3.700',
#      'american': 270,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.057938',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '1.95',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '51.28%',
#      'dp3': '1.950',
#      'american': -106,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.057946',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 271057011,
#    'name': 'Betway',
#    'odds': [{'value': '3.80',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '26.32%',
#      'dp3': '3.800',
#      'american': 280,
#      'factional': None,
#      'winning': True,
#      'stop': True,
#      'bookmaker_event_id': '7828306',
#      'last_update': {'date': '2021-08-13 18:56:07.389476',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': '7828306',
#      'last_update': {'date': '2021-08-13 18:56:07.389497',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.15',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '46.51%',
#      'dp3': '2.150',
#      'american': 114,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': '7828306',
#      'last_update': {'date': '2021-08-13 18:56:07.389507',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 88,
#    'name': 'Tipico',
#    'odds': [{'value': '3.70',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '27.03%',
#      'dp3': '3.700',
#      'american': 270,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.072844',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.072859',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.05',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '48.78%',
#      'dp3': '2.050',
#      'american': 104,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.073041',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 13,
#    'name': 'BetCRIS',
#    'odds': [{'value': '3.90',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.64%',
#      'dp3': '3.900',
#      'american': 290,
#      'factional': None,
#      'winning': True,
#      'stop': True,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.080626',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.25',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.77%',
#      'dp3': '3.250',
#      'american': 225,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.080642',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.10',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '47.62%',
#      'dp3': '2.100',
#      'american': 110,
#      'factional': None,
#      'winning': False,
#      'stop': True,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.080651',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 7,
#    'name': '888Sport',
#    'odds': [{'value': '3.30',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '30.3%',
#      'dp3': '3.300',
#      'american': 229,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.087883',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.85',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.97%',
#      'dp3': '3.850',
#      'american': 285,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:57:14.844938',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.07',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '48.31%',
#      'dp3': '2.070',
#      'american': 106,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:57:14.844964',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 25,
#    'name': 'Dafabet',
#    'odds': [{'value': '3.90',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '25.64%',
#      'dp3': '3.900',
#      'american': 290,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.095505',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.20',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '31.25%',
#      'dp3': '3.200',
#      'american': 220,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.095518',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '2.13',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '46.95%',
#      'dp3': '2.130',
#      'american': 112,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': None,
#      'last_update': {'date': '2021-08-13 18:45:12.095526',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]},
#   {'id': 187,
#    'name': 'WilliamHill',
#    'odds': [{'value': '4.33',
#      'handicap': None,
#      'total': None,
#      'label': '1',
#      'probability': '23.09%',
#      'dp3': '4.330',
#      'american': 333,
#      'factional': None,
#      'winning': True,
#      'stop': False,
#      'bookmaker_event_id': '965387555',
#      'last_update': {'date': '2021-08-13 18:45:11.992742',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '3.60',
#      'handicap': None,
#      'total': None,
#      'label': 'X',
#      'probability': '27.78%',
#      'dp3': '3.600',
#      'american': 260,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': '965387555',
#      'last_update': {'date': '2021-08-13 18:45:11.992754',
#       'timezone_type': 3,
#       'timezone': 'UTC'}},
#     {'value': '1.83',
#      'handicap': None,
#      'total': None,
#      'label': '2',
#      'probability': '54.64%',
#      'dp3': '1.830',
#      'american': -121,
#      'factional': None,
#      'winning': False,
#      'stop': False,
#      'bookmaker_event_id': '965387555',
#      'last_update': {'date': '2021-08-13 18:45:11.992763',
#       'timezone_type': 3,
#       'timezone': 'UTC'}}]}]}

# %% [markdown]
# Fetch markets

# %%
markets_df = sm.get_markets()
markets_df.head(3)
# Out:
#    id         name
# 0   1  3Way Result
# 1  10    Home/Away
# 2  12   Over/Under

# %% [markdown]
# Fetch bookmakers

# %%
bookmakers_df = sm.get_bookmakers()
bookmakers_df.head(3)
# Out:
#    id    name  logo
# 0   1   10Bet  None
# 1   2  bet365  None
# 2   3  188Bet  None
