# %% [markdown]
# This notebook is used to demo fetching data and saving data from Sportmonks used for future projects. What is in scope is to get all fixtures for Europe's top five leagues for the past 5 seasons.

# %% [markdown]
# # Imports

# %%
import json
import pandas as pd
from sportmonks_class import Sportmonks
from sportmonks_config import (
    FIXTURES_EVENT_INCLUDES,
    FIXTURES_ODDS_INCLUDES,
)

# %% [markdown]
# # Functions

# %%
def save_dict(json_file, file_path):
    '''Function used to save json data'''
    # json
    with open(file_path, 'w') as file:
        json.dump(json_file, file)

# %% [markdown]
# # Instantiate Sportmonks Class

# %%
sm = Sportmonks()

# %% [markdown]
# # Fetch league ids of interest

# %%
leagues_df = sm.get_leagues()
# Out:
#       id  active      type  legacy_id  country_id  \
# 0      8    True  domestic         29         462
# 1     72    True  domestic          1          38
# 2     82    True  domestic          4          11
# 3    271    True  domestic         43         320
# 4    301    True  domestic         47          17
# 5    384    True  domestic         22         251
# 6    462    True  domestic         16          20
# 7    501    True  domestic         66        1161
# 8    564    True  domestic         19          32
# 9    600    True  domestic         46         404
# 10   636    True  domestic         35          44
# 11   648    True  domestic        164           5
# 12   672    True  domestic        201         353
# 13   743    True  domestic         58         458
# 14   764    True  domestic        199         338
# 15   779    True  domestic        233        3483
# 16   989    True  domestic        175        5618
# 17  1356    True  domestic        107          98
#
#                                             logo_path                 name  \
# 0   https://cdn.sportmonks.com/images/soccer/leagu...       Premier League
# 1   https://cdn.sportmonks.com/images/soccer/leagu...           Eredivisie
# 2   https://cdn.sportmonks.com/images/soccer/leagu...           Bundesliga
# 3   https://cdn.sportmonks.com/images/soccer/leagu...            Superliga
# 4   https://cdn.sportmonks.com/images//soccer/leag...              Ligue 1
# 5   https://cdn.sportmonks.com/images//soccer/leag...              Serie A
# 6   https://cdn.sportmonks.com/images//soccer/leag...        Liga Portugal
# 7   https://cdn.sportmonks.com/images/soccer/leagu...          Premiership
# 8   https://cdn.sportmonks.com/images/soccer/leagu...              La Liga
# 9   https://cdn.sportmonks.com/images/soccer/leagu...            Super Lig
# 10  https://cdn.sportmonks.com/images/soccer/leagu...            Superliga
# 11  https://cdn.sportmonks.com/images/soccer/leagu...              Serie A
# 12  https://cdn.sportmonks.com/images/soccer/leagu...         Liga BetPlay
# 13  https://cdn.sportmonks.com/images/soccer/leagu...              Liga MX
# 14  https://cdn.sportmonks.com/images/soccer/leagu...     Primera Division
# 15  https://cdn.sportmonks.com/images/soccer/leagu...  Major League Soccer
# 16  https://cdn.sportmonks.com/images/soccer/leagu...         Super League
# 17  https://cdn.sportmonks.com/images/soccer/leagu...             A-League
#
#     is_cup  is_friendly  current_season_id  current_round_id  \
# 0    False        False              19734          274676.0
# 1    False        False              19726          274590.0
# 2    False        False              19744          274912.0
# 3    False        False              19686          274241.0
# 4    False        False              19745          274942.0
# 5    False        False              19806          276005.0
# 6    False        False              19896          277459.0
# 7    False        False              19735          274720.0
# 8    False        False              19799          275889.0
# 9    False        False              19900          277531.0
# 10   False        False              19353          273887.0
# 11   False        False              19434          268733.0
# 12   False        False              19326          266414.0
# 13   False        False              19684          273911.0
# 14   False        False              19267          265314.0
# 15   False        False              19137               NaN
# 16   False        False              19679          284028.0
# 17   False        False              20243               NaN
#
#     current_stage_id  live_standings  coverage.predictions  \
# 0         77457864.0            True                  True
# 1         77457832.0            True                  True
# 2         77457883.0            True                  True
# 3         77457696.0            True                  True
# 4         77457884.0            True                  True
# 5         77458057.0            True                  True
# 6         77458262.0            True                  True
# 7         77457866.0            True                  True
# 8         77458033.0            True                  True
# 9         77458273.0            True                  True
# 10        77456564.0            True                  True
# 11        77456834.0            True                  True
# 12        77456472.0            True                  True
# 13        77457688.0            True                  True
# 14        77456294.0            True                  True
# 15        77456086.0            True                  True
# 16        77457668.0            True                  True
# 17               NaN            True                  True
#
#     coverage.topscorer_goals  coverage.topscorer_assists  \
# 0                       True                        True
# 1                       True                        True
# 2                       True                        True
# 3                       True                        True
# 4                       True                        True
# 5                       True                        True
# 6                       True                        True
# 7                       True                        True
# 8                       True                        True
# 9                       True                        True
# 10                      True                        True
# 11                      True                        True
# 12                      True                        True
# 13                      True                        True
# 14                      True                        True
# 15                      True                        True
# 16                      True                        True
# 17                      True                        True
#
#     coverage.topscorer_cards
# 0                       True
# 1                       True
# 2                       True
# 3                       True
# 4                       True
# 5                       True
# 6                       True
# 7                       True
# 8                       True
# 9                       True
# 10                      True
# 11                      True
# 12                      True
# 13                      True
# 14                      True
# 15                      True
# 16                      True
# 17                      True

# %%
top_5_leagues_df = leagues_df[leagues_df['id'].isin([8,82,301,564,384])]

# %%
top_5_dict = dict(zip(top_5_leagues_df.id, top_5_leagues_df.name))
top_5_dict
# Out:
# {8: 'Premier League',
#  82: 'Bundesliga',
#  301: 'Ligue 1',
#  384: 'Serie A',
#  564: 'La Liga'}

# %% [markdown]
# # Fetch seasons of interest
#
# Looking to get last 5 seasons worth of data

# %%
# first batch
# years_of_interest = [
#     '2017/2018',
#     '2018/2019',
#     '2019/2020',
#     '2020/2021',
#     '2021/2022'
# ]

# second batch
years_of_interest = [  
 '2010/2011',
 '2011/2012',
 '2012/2013',
 '2013/2014',
 '2014/2015',
 '2015/2016',
 '2016/2017',
]

# %%
seasons_json = sm.get_seasons()
seasons_df = pd.DataFrame(seasons_json)

# %% [markdown]
# # Basic data to be saved
#
# Fetch data

# %%
# dataframes
countries_df = sm.get_countries()
leagues_df = sm.get_leagues()

# json files
seasons_json = sm.get_seasons()

# %% [markdown]
# Save data

# %%
# df
countries_df.to_csv('sportmonks_data/countries.csv', index=False)
leagues_df.to_csv('sportmonks_data/leagues.csv',index=False)

# json
save_dict(seasons_json, 'sportmonks_data/seasons.json')

# %% [markdown]
# # Fixtures data
#
# NB: changed saving location for more past seasons

# %%
seasons_json = sm.get_seasons()

# for league_id in top_5_dict.keys():
for league_id in [8,82,301,384,564]:
#     for year in years_of_interest:
    for year in years_of_interest:
        # year format
        year_format = year.replace('/','_')
        print(f"Persisting data for league with league_id: {league_id} and year: {year}")
        
        # fetch data
        season_id = seasons_df.loc[lambda dfr: (dfr['league_id']==league_id) & (dfr['name']==year), 'id'].iloc[0]
        
        fixtures_w_events_json = sm.get_season_fixtures(
            season_id, 
            includes_list = FIXTURES_EVENT_INCLUDES,
            seasons_json=seasons_json
        )
        
        fixtures_w_odds_json = sm.get_season_fixtures(
            season_id, 
            includes_list = FIXTURES_ODDS_INCLUDES,
            seasons_json=seasons_json
        )
        
        # save data
        save_dict(
            fixtures_w_events_json, 
            f'sportmonks_data/further_past_seasons/fixtures_w_events_{league_id}_{year_format}.json'
        )
        print('Events data saved.')
        save_dict(
            fixtures_w_odds_json, 
            f'sportmonks_data/further_past_seasons/fixtures_w_odds_{league_id}_{year_format}.json'
        )
        print('Odds data saved.')
# Out:
# Persisting data for league with league_id: 8 and year: 2010/2011
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2011/2012
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2012/2013
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2013/2014
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2014/2015
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2015/2016
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 8 and year: 2016/2017
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2010/2011
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2011/2012
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2012/2013
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2013/2014
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2014/2015
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2015/2016
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 82 and year: 2016/2017
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2010/2011
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2011/2012
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2012/2013
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2013/2014
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2014/2015
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2015/2016
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 301 and year: 2016/2017
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2010/2011
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2011/2012
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2012/2013
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2013/2014
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2014/2015
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2015/2016
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 384 and year: 2016/2017
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2010/2011
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2011/2012
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2012/2013
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2013/2014
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2014/2015
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2015/2016
# Events data saved.
# Odds data saved.
# Persisting data for league with league_id: 564 and year: 2016/2017
# Events data saved.
# Odds data saved.

# %% [markdown]
# # Demo fetching data saved

# %%
league_id = 8 
year_format = '2017_2018'
with open(f'sportmonks_data/fixtures_w_odds_{league_id}_{year_format}.json', 'r') as file_loaded:	
	data = json.load(file_loaded)

# %%
league_id = 564
year_format = '2016_2017'
with open(f'sportmonks_data/further_past_seasons/fixtures_w_events_{league_id}_{year_format}.json', 'r') as file_loaded:	
	event_data = json.load(file_loaded)

# %%
event_data[0].keys()
# Out:
# dict_keys(['id', 'league_id', 'season_id', 'stage_id', 'round_id', 'group_id', 'aggregate_id', 'venue_id', 'referee_id', 'localteam_id', 'visitorteam_id', 'winner_team_id', 'weather_report', 'commentaries', 'attendance', 'pitch', 'details', 'neutral_venue', 'winning_odds_calculated', 'formations', 'scores', 'time', 'coaches', 'standings', 'assistants', 'leg', 'colors', 'deleted', 'is_placeholder', 'localTeam', 'visitorTeam', 'substitutions', 'goals', 'cards', 'other', 'corners', 'lineup', 'bench', 'sidelined', 'stats', 'referee', 'events', 'localCoach', 'visitorCoach'])

# %%
league_id = 8
year_format = '2015_2016'
with open(f'sportmonks_data/further_past_seasons/fixtures_w_odds_{league_id}_{year_format}.json', 'r') as file_loaded:	
	odds_data = json.load(file_loaded)

# %%
odds_data[0]['odds']
# Out:
# []

# %%
# NB: prem season 18/29 didn't work tt
# do some work on quality control of data loaded
