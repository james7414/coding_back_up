# %%
import json
import pandas as pd

# %% [markdown]
# # Competitions available from free Statsbomb data

# %% [markdown]
# load competitions data

# %%
with open('data/competitions.json', 'r') as file_loaded:
    comp_data = json.load(file_loaded)

# %% [markdown]
# competitions data

# %%
competitions_df = pd.DataFrame(comp_data)
competitions_df
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# ...

# %% [markdown]
# # Matches data

# %%
with open('data/matches/37/4.json', 'r') as file_loaded:
    season = json.load(file_loaded)
    
with open('data/matches/37/42.json', 'r') as file_loaded:
    season = json.load(file_loaded)
    
with open('data/matches/37/90.json', 'r') as file_loaded:
    season = json.load(file_loaded)

# %%
pd.DataFrame(season)
# Out:
#      match_id  match_date      kick_off  \
# 0     3775648  2021-02-28  15:00:00.000
# 1     3775609  2021-04-28  20:30:00.000
# 2     3775633  2021-02-06  13:30:00.000
# 3     3775570  2021-03-28  13:30:00.000
# 4     3775581  2021-03-28  15:30:00.000
# ..        ...         ...           ...
# 126   3775608  2021-01-17  16:00:00.000
# 127   3775599  2021-04-20  19:00:00.000
# 128   3775554  2020-11-14  17:30:00.000
# 129   3775652  2021-02-07  15:00:00.000
# 130   3764238  2020-09-12  18:20:00.000
#
#                                            competition  \
# 0    {'competition_id': 37, 'country_name': 'Englan...
# 1    {'competition_id': 37, 'country_name': 'Englan...
# 2    {'competition_id': 37, 'country_name': 'Englan...
# 3    {'competition_id': 37, 'country_name': 'Englan...
# 4    {'competition_id': 37, 'country_name': 'Englan...
# ..                                                 ...
# 126  {'competition_id': 37, 'country_name': 'Englan...
# ...

# %%
# I have only manually uploaded data for one season of the WSL
