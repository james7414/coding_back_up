# %% [markdown]
# # Visualization with Matplotlib, Pandas, and Seaborn

# %% [markdown]
# Change directory

# %%
import os
import matplotlib.pyplot as plt

os.chdir("../../")
os.getcwd()
# Out:
# "C:\\Users\\k2035549\\OneDrive - King's College London\\Desktop\\Coding\\cookbook"

# %%
import pandas as pd

# when reading data use following path: coding_data/cookbook_data

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Getting started with matplotlib

# %%
# %matplotlib inline

# %% [markdown]
# ## Object-oriented guide to matplotlib
#
# Statefil interface of matplotlib

# %%
import matplotlib.pyplot as plt
x = [-3, 5, 7]
y = [10, 2, 5]
fig = plt.figure(figsize=(15,3))
plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size=20, y=1.03)
fig.savefig('c13-fig1.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# object oriented approah

# %%
from matplotlib.figure import Figure
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from IPython.core.display import display
fig = Figure(figsize=(15, 3))
FigureCanvas(fig)  
ax = fig.add_subplot(111)
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-3, 8)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_title('Line Plot')
fig.suptitle('Figure Title', size=20, y=1.03)
display(fig)
fig.savefig('c13-fig2.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax.plot(x, y)
ax.set(xlim=(0, 10), ylim=(-3, 8),
    xlabel='X axis', ylabel='Y axis',
    title='Line Plot')
fig.suptitle('Figure Title', size=20, y=1.03)
fig.savefig('c13-fig3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### How to do it...

# %%
import matplotlib.pyplot as plt

# %%
# create a figure and oen or more axes object (one in this case)
fig, ax = plt.subplots(nrows=1, ncols=1)
# fig.savefig('c13-step2.png', dpi=300)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
# making the figure bigger

fig.set_size_inches(14, 4)
# fig.savefig('c13-step4.png', dpi=300)         
fig

# %%
fig.axes

# %%
# can grab axes from fig object which we unpacked as ax already
fig.axes[0] is ax
# Out:
# True

# %%
# setting colour for figure and axes

fig.set_facecolor('.7')
ax.set_facecolor('.5')
# fig.savefig('c13-step7.png', dpi=300, facecolor='.7')  
fig

# %%
ax_children = ax.get_children()
ax_children
# Out:
# [<matplotlib.spines.Spine at 0x164a9a3a1f0>,
#  <matplotlib.spines.Spine at 0x164a93ff460>,
#  <matplotlib.spines.Spine at 0x164aa2c23d0>,
#  <matplotlib.spines.Spine at 0x164aa2b0cd0>,
#  <matplotlib.axis.XAxis at 0x164a4b77a00>,
#  <matplotlib.axis.YAxis at 0x164a9a3a610>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x164a9a449a0>]

# %%
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x164a9a3a1f0>),
#              ('right', <matplotlib.spines.Spine at 0x164a93ff460>),
#              ('bottom', <matplotlib.spines.Spine at 0x164aa2c23d0>),
#              ('top', <matplotlib.spines.Spine at 0x164aa2b0cd0>)])

# %% [markdown]
# Setting left spine of graph to move right, thicker
#
# Setting bottom spine to disappear

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)
spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
# fig.savefig('c13-step10.png', dpi=300, facecolor='.7')
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2,
    color='black', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana',
    fontsize=15)
ax.set_ylabel('Y Axis', family='Gotham', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
# fig.savefig('c13-step11.png', dpi=300, facecolor='.7')         
fig

# %% [markdown]
# ### How it works...

# %%
plot_objects = plt.subplots(nrows=1, ncols=1)
type(plot_objects)
# Out:
# tuple

# %%
fig = plot_objects[0]
ax = plot_objects[1]
fig.savefig('c13-1-works1.png', dpi=300)

# %%
fig, axs = plt.subplots(2, 4)
fig.savefig('c13-1-works2.png', dpi=300)

# %%
axs
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f6a9588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f584f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266e7438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267459e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1267a6f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126817588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1268fdb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1269740f0>]],
#       dtype=object)

# %%
ax = axs[0][0]
fig.axes == fig.get_axes()
# Out:
# True

# %%
ax.xaxis == ax.get_xaxis()
# Out:
# True

# %%
ax.yaxis == ax.get_yaxis()
# Out:
# True

# %% [markdown]
# ### There's more...

# %%
ax.xaxis.properties()
# Out:
# {'agg_filter': None,
#  'alpha': None,
#  'animated': False,
#  'children': [Text(0.5, 121.80363636363634, ''),
#   Text(1, 122.80363636363634, ''),
#   <matplotlib.axis.XTick at 0x11f6779b0>,
#   <matplotlib.axis.XTick at 0x11cf8ab00>,
#   <matplotlib.axis.XTick at 0x1269ceba8>],
#  'clip_box': <matplotlib.transforms.TransformedBbox at 0x11cf38c18>,
#  'clip_on': True,
#  'clip_path': None,
#  'contains': None,
#  'data_interval': array([ inf, -inf]),
#  'figure': <Figure size 432x288 with 8 Axes>,
#  'gid': None,
#  'gridlines': <a list of 3 Line2D gridline objects>,
#  'in_layout': True,
#  'inverted': False,
#  'label': Text(0.5, 121.80363636363634, ''),
#  'label_position': 'bottom',
#  'label_text': '',
#  'major_formatter': <matplotlib.ticker.ScalarFormatter at 0x11cf8a2e8>,
#  'major_locator': <matplotlib.ticker.AutoLocator at 0x11f5f4a90>,
#  'major_ticks': [<matplotlib.axis.XTick at 0x11f6779b0>,
#   <matplotlib.axis.XTick at 0x11cf8ab00>,
#   <matplotlib.axis.XTick at 0x1269ceba8>],
#  'majorticklabels': <a list of 3 Text major ticklabel objects>,
#  'majorticklines': <a list of 6 Line2D ticklines objects>,
#  'majorticklocs': array([0. , 0.5, 1. ]),
#  'minor_formatter': <matplotlib.ticker.NullFormatter at 0x11cf97748>,
#  'minor_locator': <matplotlib.ticker.NullLocator at 0x11f6a9ac8>,
#  'minor_ticks': [],
#  'minorticklabels': <a list of 0 Text minor ticklabel objects>,
#  'minorticklines': <a list of 0 Line2D ticklines objects>,
#  'minorticklocs': [],
#  'minpos': inf,
#  'offset_text': Text(1, 122.80363636363634, ''),
#  'path_effects': [],
#  'picker': None,
#  'pickradius': 15,
#  'rasterized': None,
#  'remove_overlapping_locs': True,
#  'scale': 'linear',
#  'sketch_params': None,
#  'smart_bounds': False,
#  'snap': None,
#  'tick_padding': 3.5,
#  'tick_space': 2,
#  'ticklabels': <a list of 3 Text major ticklabel objects>,
#  'ticklines': <a list of 6 Line2D ticklines objects>,
#  'ticklocs': array([0. , 0.5, 1. ]),
#  'ticks_direction': array(['out', 'out', 'out'], dtype='<U3'),
#  'ticks_position': 'bottom',
#  'transform': <matplotlib.transforms.IdentityTransform at 0x11cd9b550>,
#  'transformed_clip_path_and_affine': (None, None),
#  'units': None,
#  'url': None,
#  'view_interval': array([0., 1.]),
#  'visible': True,
#  'zorder': 1.5}

# %% [markdown]
# ## Visualizing data with matplotlib

# %% [markdown]
# ### How to do it...

# %%
import pandas as pd
import numpy as np
alta = pd.read_csv('data/alta-noaa-1980-2019.csv')
alta.head(3)
# Out:
#        STATION         NAME  LATITUDE  LONGITUDE  ELEVATION        DATE  DAPR  \
# 0  USC00420072  ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-01   NaN
# 1  USC00420072  ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-02   NaN
# 2  USC00420072  ALTA, UT US   40.5905  -111.6369     2660.9  1980-01-03   NaN
#
#    DASF  MDPR  MDSF  ...  SNWD  TMAX  TMIN  TOBS  WT01  WT03  WT04  WT05  \
# 0   NaN   NaN   NaN  ...  29.0  38.0  25.0  25.0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN  ...  34.0  27.0  18.0  18.0   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN  ...  30.0  27.0  12.0  18.0   NaN   NaN   NaN   NaN
#
#    WT06  WT11
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
#
# [3 rows x 22 columns]

# %% [markdown]
# Select data for 2018-2019 season and grab snowfall column (snow depth)

# %%
data = (alta
    .assign(DATE=pd.to_datetime(alta.DATE))
    .set_index('DATE')
    .loc['2018-09':'2019-08']
    .SNWD
)
data
# Out:
# DATE
# 2018-09-01    0.0
# 2018-09-02    0.0
# 2018-09-03    0.0
# 2018-09-04    0.0
# 2018-09-05    0.0
#              ...
# 2019-08-27    0.0
# 2019-08-28    0.0
# 2019-08-29    0.0
# 2019-08-30    0.0
# 2019-08-31    0.0
# Name: SNWD, Length: 364, dtype: float64

# %%
blue = '#99ddee'
white = '#ffffff'
fig, ax = plt.subplots(figsize=(12,4), 
     linewidth=5, facecolor=blue)
ax.set_facecolor(blue)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.tick_params(axis='x', colors=white)
ax.tick_params(axis='y', colors=white)
ax.set_ylabel('Snow Depth (in)', color=white)
ax.set_title('2009-2010', color=white, fontweight='bold')
ax.fill_between(data.index, data, color=white)
# fig.savefig('c13-alta1.png', dpi=300, facecolor=blue)

# %%
import matplotlib.dates as mdt
blue = '#99ddee'
white = '#ffffff'

# %%
axes.flatten()
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5D51D2E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5D3CF220>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5D13BD00>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5D0EB2B0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5D1048E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5CF83280>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5C67C7C0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5C833910>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5AEFD100>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001EF5C7ACB80>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
years = range(2009,2019)
blue = '#99ddee'
white = '#ffffff'

fig, axes = plt.subplots(nrows=2, ncols=5,figsize=(30,10), 
     linewidth=5, facecolor=blue)

axes = axes.flatten()

for i, year in enumerate(years):
    row_no = int(i/5)
    col_no = i % 5
    ax = axes[i]
    data = (
        alta
        .assign(DATE=pd.to_datetime(alta.DATE))
        .set_index('DATE')
        .loc[f'{year}-09':f'{year+1}-08']
        .SNWD
    )
    year_range = f'{year} : {year+1}'
    plot_year(ax, data, year_range)

# %%
def plot_year(ax, data, years):
    ax.set_facecolor(blue)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.tick_params(axis='x', colors=white)
    ax.tick_params(axis='y', colors=white)
    ax.set_ylabel('Snow Depth (in)', color=white)
    ax.set_title(years, color=white, fontweight='bold')
    ax.fill_between(data.index, data, color=white)

# %% [markdown]
# Multiple plots

# %%
years = range(2009, 2019)
fig, axs = plt.subplots(ncols=2, nrows=int(len(years)/2), 
    figsize=(16, 10), linewidth=5, facecolor=blue)
axs = axs.flatten()
max_val = None
max_data = None
max_ax = None
for i,y in enumerate(years):
    ax = axs[i]
    data = (alta
       .assign(DATE=pd.to_datetime(alta.DATE))
       .set_index('DATE')
       .loc[f'{y}-09':f'{y+1}-08']
       .SNWD
    )
    if max_val is None or max_val < data.max():
        max_val = data.max()
        max_data = data
        max_ax = ax
    ax.set_ylim(0, 180)
    years = f'{y}-{y+1}'
    plot_year(ax, data, years)
max_ax.annotate(f'Max Snow {max_val}', 
   xy=(mdt.date2num(max_data.idxmax()), max_val), 
   color=white)
# Out:
# Text(734236.0, 168.0, 'Max Snow 168.0')

# %%
fig.suptitle('Alta Snowfall', color=white, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.savefig('c13-alta2.png', dpi=300, facecolor=blue)

# %% [markdown]
# ### How it works...

# %% [markdown]
# ### There's more...

# %%
years = range(2009, 2019)
fig, axs = plt.subplots(ncols=2, nrows=int(len(years)/2), 
    figsize=(16, 10), linewidth=5, facecolor=blue)
axs = axs.flatten()
max_val = None
max_data = None
max_ax = None
for i,y in enumerate(years):
    ax = axs[i]
    data = (alta.assign(DATE=pd.to_datetime(alta.DATE))
       .set_index('DATE')
       .loc[f'{y}-09':f'{y+1}-08']
       .SNWD
       .interpolate()
    )
    if max_val is None or max_val < data.max():
        max_val = data.max()
        max_data = data
        max_ax = ax
    ax.set_ylim(0, 180)
    years = f'{y}-{y+1}'
    plot_year(ax, data, years)
max_ax.annotate(f'Max Snow {max_val}', 
   xy=(mdt.date2num(max_data.idxmax()), max_val), 
   color=white)
plt.tight_layout()

# %%
fig.suptitle('Alta Snowfall', color=white, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.savefig('c13-alta3.png', dpi=300, facecolor=blue)

# %%
(alta
    .assign(DATE=pd.to_datetime(alta.DATE))
    .set_index('DATE')
    .SNWD
    .to_frame()
    .assign(next=lambda df_:df_.SNWD.shift(-1),
            snwd_diff=lambda df_:df_.next-df_.SNWD)
    .pipe(lambda df_: df_[df_.snwd_diff.abs() > 50])
)
# Out:
#             SNWD   next  snwd_diff
# DATE
# 1989-11-27  60.0    0.0      -60.0
# 2007-02-28  87.0    9.0      -78.0
# 2008-05-22  62.0    0.0      -62.0
# 2008-05-23   0.0   66.0       66.0
# 2009-01-16  76.0    0.0      -76.0
# ...          ...    ...        ...
# 2011-05-18   0.0  136.0      136.0
# 2012-02-09  58.0    0.0      -58.0
# 2012-02-10   0.0   56.0       56.0
# 2013-03-01  75.0    0.0      -75.0
# 2013-03-02   0.0   78.0       78.0
#
# [21 rows x 3 columns]

# %%
def fix_gaps(ser, threshold=50):
    'Replace values where the shift is > threshold with nan'
    mask = (ser
       .to_frame()
       .assign(next=lambda df_:df_.SNWD.shift(-1),
               snwd_diff=lambda df_:df_.next-df_.SNWD)
       .pipe(lambda df_: df_.snwd_diff.abs() > threshold)
    )
    return ser.where(~mask, np.nan) 
# note where has a pass argument ie ~mask which means if a value does not pass that condition then we replace with np.nan

# %%
years = range(2009, 2019)
fig, axs = plt.subplots(ncols=2, nrows=int(len(years)/2), 
    figsize=(16, 10), linewidth=5, facecolor=blue)
axs = axs.flatten()
max_val = None
max_data = None
max_ax = None
for i,y in enumerate(years):
    ax = axs[i]
    data = (alta.assign(DATE=pd.to_datetime(alta.DATE))
       .set_index('DATE')
       .loc[f'{y}-09':f'{y+1}-08']
       .SNWD
       .pipe(fix_gaps)
       .interpolate()
    )
    if max_val is None or max_val < data.max():
        max_val = data.max()
        max_data = data
        max_ax = ax
    ax.set_ylim(0, 180)
    years = f'{y}-{y+1}'
    plot_year(ax, data, years)
max_ax.annotate(f'Max Snow {max_val}', 
   xy=(mdt.date2num(max_data.idxmax()), max_val), 
   color=white)
# Out:
# Text(734236.0, 168.0, 'Max Snow 168.0')

# %%
fig.suptitle('Alta Snowfall', color=white, fontweight='bold')
fig.tight_layout(rect=[0, 0.03, 1, 0.95])
fig.savefig('c13-alta4.png', dpi=300, facecolor=blue)

# %% [markdown]
# ## Plotting basics with pandas

# %% [markdown]
# ### How to do it..

# %%
df = pd.DataFrame(index=['Atiya', 'Abbas', 'Cornelia',
    'Stephanie', 'Monte'],
    data={'Apples':[20, 10, 40, 20, 50],
          'Oranges':[35, 40, 25, 19, 33]})

# %%
df
# Out:
#            Apples  Oranges
# Atiya          20       35
# Abbas          10       40
# Cornelia       40       25
# Stephanie      20       19
# Monte          50       33

# %%
color = ['.2', '.7']
ax = df.plot.bar(color=color, figsize=(16,4))
# ax.get_figure().savefig('c13-pdemo-bar1.png', dpi=300, bbox_inches='tight')

# %%
ax = df.plot.kde(color=color, figsize=(16,4))
ax.get_figure().savefig('c13-pdemo-kde1.png')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('Two Variable Plots', size=20, y=1.02)
df.plot.line(ax=ax1, title='Line plot')
df.plot.scatter(x='Apples', y='Oranges', 
    ax=ax2, title='Scatterplot')
df.plot.bar(color=color, ax=ax3, title='Bar plot')
fig.savefig('c13-pdemo-scat.png', dpi=300, bbox_inches='tight')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('One Variable Plots', size=20, y=1.02)
df.plot.kde(color=color, ax=ax1, title='KDE plot')
df.plot.box(ax=ax2, title='Boxplot')
df.plot.hist(color=color, ax=ax3, title='Histogram')
fig.savefig('c13-pdemo-kde2.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ### There's more...

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
df.sort_values('Apples').plot.line(x='Apples', y='Oranges',
      ax=ax1)
df.plot.bar(x='Apples', y='Oranges', ax=ax2)
df.plot.kde(x='Apples', ax=ax3)
fig.savefig('c13-pdemo-kde3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Visualizing the flights dataset (annotating from here)

# %% [markdown]
# ### How to do it...

# %%
# load data
import pandas as pd
flights = pd.read_csv('data/flights.csv')
flights.head(3)
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0

# %%
# adding DELAYED and ON_TIME column

cols = ['DIVERTED', 'CANCELLED', 'DELAYED']

(flights
    .assign(DELAYED=flights['ARR_DELAY'].ge(15).astype(int),
            ON_TIME=lambda df_:1 - df_[cols].any(axis=1))
    .select_dtypes([int,'int64'])
    .sum()
)
# Out:
# MONTH          363858
# DAY            918447
# WEEKDAY        229690
# SCHED_DEP    81186009
# DIST         51057671
# SCHED_ARR    90627495
# DIVERTED          137
# CANCELLED         881
# DELAYED         11685
# ON_TIME         45789
# dtype: int64

# %%
# plot univariate graphs to get more information

fig, ax_array = plt.subplots(2, 3, figsize=(18,8))
(ax1, ax2, ax3), (ax4, ax5, ax6) = ax_array

fig.suptitle('2015 US Flights - Univariate Summary', size=20)

ac = flights['AIRLINE'].value_counts()

# horizontal barplot
ac.plot.barh(ax=ax1, title='Airline')

# bar plot for origin airports (only have ten)
(flights
    ['ORG_AIR']
    .value_counts()
    .plot.bar(ax=ax2, rot=0, title='Origin City')
)

# bar plot for destination airports (most visited)
(flights
    ['DEST_AIR']
    .value_counts()
    .head(10)
    .plot.bar(ax=ax3, rot=0, title='Destination City')
)

# bar plot for number of flights that are ontime, delayed, diverted and cancelled
(flights
    .assign(DELAYED=flights['ARR_DELAY'].ge(15).astype(int),
            ON_TIME=lambda df_:1 - df_[cols].any(axis=1))
    [['DIVERTED', 'CANCELLED', 'DELAYED', 'ON_TIME']]
    .sum()
    .plot.bar(ax=ax4, rot=0,
         log=True, title='Flight Status')
)

# kde sketch
flights['DIST'].plot.kde(ax=ax5, xlim=(0, 3000), # limit x as don't want a plot to show impossible values
    title='Distance KDE')

# histogram for arrival delay
flights['ARR_DELAY'].plot.hist(ax=ax6,
    title='Arrival Delay',
    range=(0,200)
)
# fig.savefig('c13-uni1.png')

# %% [markdown]
# Plotting number of flights per week.
#
# But don't have all the date information so will create the date information

# %%
df_date = (
    flights
    [['MONTH', 'DAY']]
    .assign(
        YEAR=2015, # giving any year
        HOUR=flights['SCHED_DEP'] // 100, # tiem in format HHMM as an integer
        MINUTE=flights['SCHED_DEP'] % 100
    )
)
df_date
# Out:
#        MONTH  DAY  YEAR  HOUR  MINUTE
# 0          1    1  2015    16      25
# 1          1    1  2015     8      23
# 2          1    1  2015    13       5
# 3          1    1  2015    15      55
# 4          1    1  2015    17      20
# ...      ...  ...   ...   ...     ...
# 58487     12   31  2015     5      15
# 58488     12   31  2015    19      10
# 58489     12   31  2015    18      46
# 58490     12   31  2015     5      25
# 58491     12   31  2015     8      59
#
# [58492 rows x 5 columns]

# %%
flight_dep = pd.to_datetime(df_date)
flight_dep
# Out:
# 0       2015-01-01 16:25:00
# 1       2015-01-01 08:23:00
# 2       2015-01-01 13:05:00
# 3       2015-01-01 15:55:00
# 4       2015-01-01 17:20:00
#                 ...
# 58487   2015-12-31 05:15:00
# 58488   2015-12-31 19:10:00
# 58489   2015-12-31 18:46:00
# 58490   2015-12-31 05:25:00
# 58491   2015-12-31 08:59:00
# Length: 58492, dtype: datetime64[ns]

# %%
flights.index = flight_dep

fc = flights.resample('W').size()
fc.head(3)
# Out:
# 2015-01-04     666
# 2015-01-11    1088
# 2015-01-18    1120
# Freq: W-SUN, dtype: int64

# %%
flights.index = flight_dep

fc = flights.resample('W').sum()
fc.head(3)
# Out:
#             MONTH    DAY  WEEKDAY  SCHED_DEP  DEP_DELAY  AIR_TIME    DIST  \
# 2015-01-04    666   1732     3730     913890    17504.0   75547.0  582297
# 2015-01-11   1088   8567     4215    1509959    18569.0  122862.0  950575
# 2015-01-18   1120  16731     4411    1523619     8787.0  128173.0  973169
#
#             SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 2015-01-04    1014599    15836.0         1         25
# 2015-01-11    1707480    14916.0         6         29
# 2015-01-18    1744332     4747.0         2          7

# %%
### plotting number of flights

# setting index for flights data
flights.index = flight_dep

fc = flights.resample('W').size()
fc.plot.line(figsize=(12,6), title='Flights per Week', grid=True)
# fig.savefig('c13-ts1.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# from above we can see that there is possibly data missing in october

# %%
# define function used to filling in missing data
def interp_lt_n(df_, n=600):
    return (df_
        .where(df_ > n)
        .interpolate(limit_direction='both')
)

# set your figure and axes
fig, ax = plt.subplots(figsize=(16,4))

# grab data, NB: requires index to be datetime which is done in steps above
# data here is the number of flights per week
data = (flights
    .resample('W')
    .size()
)

# apply interpolate function to weekly flights data
(data
    .pipe(interp_lt_n)
    .iloc[1:-1]
    .plot.line(color='black', ax=ax)
)
mask = data<600
(data
     .pipe(interp_lt_n)
     [mask]
     .plot.line(color='.8', linewidth=10)
) 
ax.annotate(xy=(.8, .55), xytext=(.8, .77),
            xycoords='axes fraction', s='missing data',
            ha='center', size=20, arrowprops=dict())
ax.set_title('Flights per Week (Interpolated Missing Data)')
# fig.savefig('c13-ts2.png')
# Out:
# Text(0.5, 1.0, 'Flights per Week (Interpolated Missing Data)')

# %% [markdown]
# Now we have replaced the missing data, abot shows that summar months has a lot more air traffic.
#
# Now let's have a look at multivariate plotting.
#
# Plot below:
#
# 10 airports with i) longest average distance traveled for inbound flights ii) have a minimum of 100 total flights

# %%
fig, ax = plt.subplots(figsize=(16,4))
(flights
    .groupby('DEST_AIR')
    ['DIST'] 
    .agg(['mean', 'count']) 
    .query('count > 100') 
    .sort_values('mean') 
    .tail(10) 
    .plot.bar(y='mean', rot=0, legend=False, ax=ax, # legend as false as not useful information and two columns so
        title='Average Distance per Destination')   # need to specify what y is 
)
# fig.savefig('c13-bar1.png')

# %% [markdown]
# Multivariable plot ie scatter plot for distance and airtime for flights below 2,000 miles

# %%
fig, ax = plt.subplots(figsize=(8,6))
(flights
    .reset_index(drop=True)
    [['DIST', 'AIR_TIME']] 
    .query('DIST <= 2000')
    .dropna()
    .plot.scatter(x='DIST', y='AIR_TIME', ax=ax, alpha=.1, s=1)
)
# fig.savefig('c13-scat1.png')

# %% [markdown]
# Appears a tight linear relationship between distance and airtime but variance increases as number of miles increases. Let's have a look at the correlation

# %%
flights[['DIST', 'AIR_TIME']].corr()
# Out:
#              DIST  AIR_TIME
# DIST      1.00000   0.98774
# AIR_TIME  0.98774   1.00000

# %%
(flights
    .reset_index(drop=True)
    [['DIST', 'AIR_TIME']] 
    .query('DIST <= 2000')
    .dropna()
    .pipe(lambda df_:pd.cut(df_.DIST, # pd.cut, places values into a specific binned group
          bins=range(0, 2001, 250)))
    .value_counts()
    .sort_index()
)
# Out:
# (0, 250]         6529
# (250, 500]      12631
# (500, 750]      11506
# (750, 1000]      8832
# (1000, 1250]     5071
# (1250, 1500]     3198
# (1500, 1750]     3885
# (1750, 2000]     1815
# Name: DIST, dtype: int64

# %%
# add bin column to data
zscore = lambda x: (x - x.mean()) / x.std()
short = (flights
    [['DIST', 'AIR_TIME']] 
    .query('DIST <= 2000')
    .dropna()
    .reset_index(drop=True)    
    .assign(BIN=lambda df_:pd.cut(df_.DIST,
        bins=range(0, 2001, 250)))
)

# %%
scores = (short
    .groupby('BIN')
    ['AIR_TIME']
    .transform(zscore)
)  
scores
# Out:
# 0        0.490966
# 1       -1.267551
# 2       -0.296749
# 3       -1.211020
# 4       -0.521999
#            ...
# 53462   -0.521999
# 53463    1.376879
# 53464   -1.255719
# 53465    0.495005
# 53466   -1.347036
# Name: AIR_TIME, Length: 53467, dtype: float64

# %%
(short.assign(SCORE=scores))
# Out:
#        DIST  AIR_TIME           BIN     SCORE
# 0       590      94.0    (500, 750]  0.490966
# 1      1452     154.0  (1250, 1500] -1.267551
# 2       641      85.0    (500, 750] -0.296749
# 3      1192     126.0  (1000, 1250] -1.211020
# 4      1363     166.0  (1250, 1500] -0.521999
# ...     ...       ...           ...       ...
# 53462  1464     166.0  (1250, 1500] -0.521999
# 53463   414      71.0    (250, 500]  1.376879
# 53464   262      46.0    (250, 500] -1.255719
# 53465   907     124.0   (750, 1000]  0.495005
# 53466   522      73.0    (500, 750] -1.347036
#
# [53467 rows x 4 columns]

# %% [markdown]
# Box plots for each bin.

# %%
fig, ax = plt.subplots(figsize=(10,6))   

(short.assign(SCORE=scores)
    .pivot(columns='BIN')
    ['SCORE']
    .plot.box(ax=ax)
)
ax.set_title('Z-Scores for Distance Groups')
# fig.savefig('c13-box2.png')
# Out:
# Text(0.5, 1.0, 'Z-Scores for Distance Groups')

# %% [markdown]
# Now let's examine points that are greater than six standard deviations away

# %%
# mask to get all outliers whcih are points 6 standard deviations away
mask = (short
    .assign(SCORE=scores)
    .pipe(lambda df_:df_.SCORE.abs() >6)
)

# %%
outliers = (flights
    [['DIST', 'AIR_TIME']] 
    .query('DIST <= 2000')
    .dropna()
    .reset_index(drop=True)
    [mask]
    .assign(PLOT_NUM=lambda df_:range(1, len(df_)+1))
)

# %%
outliers
# Out:
#        DIST  AIR_TIME  PLOT_NUM
# 14972   373     121.0         1
# 22507   907     199.0         2
# 40768   643     176.0         3
# 50141   651     164.0         4
# 52699   802     210.0         5

# %%
# scatter plot with outliers

# %%
fig, ax = plt.subplots(figsize=(8,6))

(short
    .assign(SCORE=scores)
    .plot.scatter(x='DIST', y='AIR_TIME',
                  alpha=.1, s=1, ax=ax,
                  table=outliers)
)

outliers.plot.scatter(x='DIST', y='AIR_TIME',
    s=25, ax=ax, grid=True)
outs = outliers[['AIR_TIME', 'DIST', 'PLOT_NUM']]

# add label to outlier plots
for t, d, n in outs.itertuples(index=False):
    ax.text(d + 5, t + 5, str(n))
    
plt.setp(ax.get_xticklabels(), y=.1)
plt.setp(ax.get_xticklines(), visible=False)
ax.set_xlabel('')
ax.set_title('Flight Time vs Distance with Outliers')

# fig.savefig('c13-scat3.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ## Stacking area charts to discover emerging trends

# %% [markdown]
# ### How to do it...

# %%
meetup = pd.read_csv('data/meetup_groups.csv',
    parse_dates=['join_date'], # change column to timestamp
    index_col='join_date')
meetup
# Out:
#                                            group     city state country
# join_date
# 2016-11-18 02:41:29     houston machine learning  Houston    TX      us
# 2017-05-09 14:16:37     houston machine learning  Houston    TX      us
# 2016-12-30 02:34:16     houston machine learning  Houston    TX      us
# 2016-07-18 00:48:17     houston machine learning  Houston    TX      us
# 2017-05-25 12:58:16     houston machine learning  Houston    TX      us
# ...                                          ...      ...   ...     ...
# 2017-10-07 18:05:24  houston data visualization   Houston    TX      us
# 2017-06-24 14:06:26  houston data visualization   Houston    TX      us
# 2015-10-05 17:08:40  houston data visualization   Houston    TX      us
# 2016-11-04 22:36:24  houston data visualization   Houston    TX      us
# 2016-08-02 17:47:29  houston data visualization   Houston    TX      us
#
# [7671 rows x 4 columns]

# %%
# groupby per week per group
(meetup
    .groupby([pd.Grouper(freq='W'), 'group']) # group by each week per group
    .size()
)
# Out:
# join_date   group
# 2010-11-07  houstonr                         5
# 2010-11-14  houstonr                        11
# 2010-11-21  houstonr                         2
# 2010-12-05  houstonr                         1
# 2011-01-16  houstonr                         2
#                                             ..
# 2017-10-15  houston data science            14
#             houston data visualization      13
#             houston energy data science      9
#             houston machine learning        11
#             houstonr                         2
# Length: 763, dtype: int64

# %%
# unstack so each meetup group has it's own column value for each week
(meetup
    .groupby([pd.Grouper(freq='W'), 'group']) 
    .size()
    .unstack('group', fill_value=0)
)
# Out:
# group       houston data science  houston data visualization   \
# join_date
# 2010-11-07            0                     0
# 2010-11-14            0                     0
# 2010-11-21            0                     0
# 2010-12-05            0                     0
# 2011-01-16            0                     0
# ...                 ...                   ...
# 2017-09-17           16                     2
# 2017-09-24           19                     4
# 2017-10-01           20                     6
# 2017-10-08           22                    10
# 2017-10-15           14                    13
#
# group       houston energy data science   \
# join_date
# 2010-11-07            0
# 2010-11-14            0
# 2010-11-21            0
# 2010-12-05            0
# 2011-01-16            0
# ...                 ...
# 2017-09-17            6
# 2017-09-24           16
# 2017-10-01            6
# 2017-10-08           10
# 2017-10-15            9
#
# group       houston machine learning  houstonr
# join_date
# 2010-11-07            0                      5
# 2010-11-14            0                     11
# 2010-11-21            0                      2
# 2010-12-05            0                      1
# 2011-01-16            0                      2
# ...                 ...                    ...
# 2017-09-17            5                      0
# 2017-09-24           12                      7
# 2017-10-01           20                      1
# 2017-10-08            4                      2
# 2017-10-15           11                      2
#
# [278 rows x 5 columns]

# %%
# cumulative sum
(meetup
    .groupby([pd.Grouper(freq='W'), 'group']) 
    .size()
    .unstack('group', fill_value=0)
    .cumsum()
)
# Out:
# group       houston data science  houston data visualization   \
# join_date
# 2010-11-07                     0                            0
# 2010-11-14                     0                            0
# 2010-11-21                     0                            0
# 2010-12-05                     0                            0
# 2011-01-16                     0                            0
# ...                          ...                          ...
# 2017-09-17                  2105                         1708
# 2017-09-24                  2124                         1712
# 2017-10-01                  2144                         1718
# 2017-10-08                  2166                         1728
# 2017-10-15                  2180                         1741
#
# group       houston energy data science   houston machine learning  houstonr
# join_date
# 2010-11-07                             0                         0         5
# 2010-11-14                             0                         0        16
# 2010-11-21                             0                         0        18
# 2010-12-05                             0                         0        19
# 2011-01-16                             0                         0        21
# ...                                  ...                       ...       ...
# 2017-09-17                          1886                       708      1056
# 2017-09-24                          1902                       720      1063
# 2017-10-01                          1908                       740      1064
# 2017-10-08                          1918                       744      1066
# 2017-10-15                          1927                       755      1068
#
# [278 rows x 5 columns]

# %%
# many stacked area charts use the percantage of the total for each row so that each row adds up to 1. Cue .div

(meetup
    .groupby([pd.Grouper(freq='W'), 'group']) 
    .size()
    .unstack('group', fill_value=0)
    .cumsum()
    .pipe(lambda df_: df_.div(
          df_.sum(axis='columns'), axis='index')) # (.sum) axis is columns,(.div) axis index ie sum for each row
)
# Out:
# group       houston data science  houston data visualization   \
# join_date
# 2010-11-07              0.000000                     0.000000
# 2010-11-14              0.000000                     0.000000
# 2010-11-21              0.000000                     0.000000
# 2010-12-05              0.000000                     0.000000
# 2011-01-16              0.000000                     0.000000
# ...                          ...                          ...
# 2017-09-17              0.282058                     0.228862
# 2017-09-24              0.282409                     0.227629
# 2017-10-01              0.283074                     0.226829
# 2017-10-08              0.284177                     0.226712
# 2017-10-15              0.284187                     0.226959
#
# group       houston energy data science   houston machine learning  houstonr
# join_date
# 2010-11-07                      0.000000                  0.000000  1.000000
# 2010-11-14                      0.000000                  0.000000  1.000000
# 2010-11-21                      0.000000                  0.000000  1.000000
# 2010-12-05                      0.000000                  0.000000  1.000000
# 2011-01-16                      0.000000                  0.000000  1.000000
# ...                                  ...                       ...       ...
# 2017-09-17                      0.252713                  0.094868  0.141498
# 2017-09-24                      0.252892                  0.095732  0.141338
# 2017-10-01                      0.251914                  0.097703  0.140481
# 2017-10-08                      0.251640                  0.097612  0.139858
# 2017-10-15                      0.251206                  0.098423  0.139226
#
# [278 rows x 5 columns]

# %%
# set figure and axes
fig, ax = plt.subplots(figsize=(18,6))  

# plot of area plot
(meetup
    .groupby([pd.Grouper(freq='W'), 'group']) 
    .size()
    .unstack('group', fill_value=0)
    .cumsum()
    .pipe(lambda df_: df_.div(
          df_.sum(axis='columns'), axis='index'))
    .plot.area(ax=ax,
          cmap='Greys', xlim=('2013-6', None), # note done x lim with datetime string, can't do that in matplotlib
          ylim=(0, 1), legend=False)
)

#main title
ax.figure.suptitle('Houston Meetup Groups', size=25)
# no x axis label
ax.set_xlabel('')
# y ticks on right
ax.yaxis.tick_right()

kwargs = {'xycoords':'axes fraction', 'size':15}

# annotate areas
ax.annotate(xy=(.1, .7), s='R Users',
    color='w', **kwargs)
ax.annotate(xy=(.25, .16), s='Data Visualization',
    color='k', **kwargs)
ax.annotate(xy=(.5, .55), s='Energy Data Science',
    color='k', **kwargs)
ax.annotate(xy=(.83, .07), s='Data Science',
    color='k', **kwargs)
ax.annotate(xy=(.86, .78), s='Machine Learning',
    color='w', **kwargs)
# fig.savefig('c13-stacked1.png')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ## Understanding the differences between seaborn and pandas

# %% [markdown]
# ### How to do it...

# %%
employee = pd.read_csv('data/employee.csv',
    parse_dates=['HIRE_DATE', 'JOB_DATE'])
employee
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 0        121862.0            Hispanic/Latino       Full Time  Female
# 1         26125.0            Hispanic/Latino       Full Time  Female
# 2         45279.0                      White       Full Time    Male
# 3         63166.0                      White       Full Time    Male
# 4         56347.0                      White       Full Time    Male
# ...           ...                        ...             ...     ...
# 1995      43443.0                      White       Full Time    Male
# 1996      66523.0  Black or African American       Full Time    Male
# 1997      43443.0                      White       Full Time    Male
# 1998      55461.0     Asian/Pacific Islander       Full Time    Male
# 1999      51194.0            Hispanic/Latino       Full Time    Male
#
#      EMPLOYMENT_STATUS  HIRE_DATE   JOB_DATE
# 0               Active 2006-06-12 2012-10-13
# 1               Active 2000-07-19 2010-09-18
# 2               Active 2015-02-03 2015-02-03
# 3               Active 1982-02-08 1991-05-25
# 4               Active 1989-06-19 1994-10-22
# ...                ...        ...        ...
# 1995            Active 2014-06-09 2015-06-09
# 1996            Active 2003-09-02 2013-10-06
# 1997            Active 2014-10-13 2015-10-13
# 1998            Active 2009-01-20 2011-07-02
# 1999            Active 2009-01-12 2010-07-12
#
# [2000 rows x 10 columns]

# %%
import seaborn as sns

# %% [markdown]
# Countplot in seaborn and pandas plotting

# %%
fig, ax = plt.subplots(figsize=(8, 6))

sns.countplot(y='DEPARTMENT', data=employee, ax=ax)     
# fig.savefig('c13-sns1.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(8, 6))

(employee
    ['DEPARTMENT']
    .value_counts()
    .plot.barh(ax=ax)
)

# fig.savefig('c13-sns2.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# Bar plot in seaborn and pandas plot

# %%
fig, ax = plt.subplots(figsize=(8, 6))    

sns.barplot(y='RACE', x='BASE_SALARY', data=employee, ax=ax)

# fig.savefig('c13-sns3.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(8, 6))    

(employee
    .groupby('RACE', sort=False) 
    ['BASE_SALARY']
    .mean()
    .plot.barh(rot=0, width=.8, ax=ax)
)
ax.set_xlabel('Mean Salary')

# fig.savefig('c13-sns4.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 0, 'Mean Salary')

# %% [markdown]
# Seaborn can also distinguish groups within the data through a third variable hue.
#
# Plot for mean slary by race and Gender

# %%
fig, ax = plt.subplots(figsize=(18, 6))   

sns.barplot(x='RACE', y='BASE_SALARY', hue='GENDER',
    ax=ax, data=employee, palette='Greys',
    order=['Hispanic/Latino', 
           'Black or African American',
           'American Indian or Alaskan Native',
           'Asian/Pacific Islander', 'Others',
           'White'])
# fig.savefig('c13-sns5.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(18, 6))            
(employee
    .groupby(['RACE', 'GENDER'], sort=False) 
    ['BASE_SALARY']
    .mean()
    .unstack('GENDER')
    .sort_values('Female')
    .plot.bar(rot=0, ax=ax,
        width=.8, cmap='viridis')
)
# fig.savefig('c13-sns6.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# Boxplots

# %%
fig, ax = plt.subplots(figsize=(8, 6))   

sns.boxplot(x='GENDER', y='BASE_SALARY', data=employee,
            hue='RACE', palette='Greys', ax=ax)
# fig.savefig('c13-sns7.png', dpi=300, bbox_inches='tight')

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
for g, ax in zip(['Female', 'Male'], axs):
    (employee
        .query('GENDER == @g')
        .assign(RACE=lambda df_:df_.RACE.fillna('NA'))
        .pivot(columns='RACE')
        ['BASE_SALARY']
        .plot.box(ax=ax, rot=30)
    )
    ax.set_title(g + ' Salary')
    ax.set_xlabel('')
# fig.savefig('c13-sns8.png', bbox_inches='tight')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ## Multivariate analysis with seaborn Grids
#
# Looking at relationship between years of experience and salary by gender and race

# %% [markdown]
# ### How to do it...

# %%
emp = pd.read_csv('data/employee.csv',
    parse_dates=['HIRE_DATE', 'JOB_DATE'])
def yrs_exp(df_):
    days_hired = pd.to_datetime('12-1-2016') - df_.HIRE_DATE # dates minus each other returns a time delta object units in days
    return days_hired.dt.days / 365.25

# %%
emp = (emp
    .assign(YEARS_EXPERIENCE=yrs_exp)
)

# %%
emp[['HIRE_DATE', 'YEARS_EXPERIENCE']]
# Out:
#       HIRE_DATE  YEARS_EXPERIENCE
# 0    2006-06-12    10.472279
# 1    2000-07-19    16.369610
# 2    2015-02-03     1.826146
# 3    1982-02-08    34.811773
# 4    1989-06-19    27.452430
# ...         ...          ...
# 1995 2014-06-09     2.480493
# 1996 2003-09-02    13.248460
# 1997 2014-10-13     2.135524
# 1998 2009-01-20     7.863107
# 1999 2009-01-12     7.885010
#
# [2000 rows x 2 columns]

# %% [markdown]
# Plot scatter plot with regression line

# %%
fig, ax = plt.subplots(figsize=(8, 6))        
sns.regplot(x='YEARS_EXPERIENCE', y='BASE_SALARY',
    data=emp, ax=ax)
# fig.savefig('c13-scat4.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# regplot can't plot multiple regression linesm use lmplot to plot a seaborn grid that adds regression lies for male and females

# %%
grid = sns.lmplot(x='YEARS_EXPERIENCE', y='BASE_SALARY', 
    hue='GENDER', palette='Greys',
    scatter_kws={'s':10}, data=emp) # scatter kws are the scatter point sizes
grid.fig.set_size_inches(8, 6) 
# grid.fig.savefig('c13-scat5.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# Plot for each unique race the plots for years of experience and pay for males and females

# %%
grid = sns.lmplot(x='YEARS_EXPERIENCE', y='BASE_SALARY',
                  hue='GENDER', col='RACE', col_wrap=3,
                  palette='Greys', sharex=False,
                  line_kws = {'linewidth':5},
                  data=emp)
grid.set(ylim=(20000, 120000))     
# there are also parameters from the 'line' and 'scatter' plot functions from matplotlib
# to do so set the 'scatter_kws' and 'line_kws' parameters to a dictionary that has the matplotlib parameter as a
# key paired with the value

# grid.fig.savefig('c13-scat6.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ### There's more...

# %%
deps = emp['DEPARTMENT'].value_counts().index[:2]
races = emp['RACE'].value_counts().index[:3]
is_dep = emp['DEPARTMENT'].isin(deps)
is_race = emp['RACE'].isin(races)    
emp2 = (emp
    [is_dep & is_race]
    .assign(DEPARTMENT=lambda df_:
            df_['DEPARTMENT'].str.extract('(HPD|HFD)',
                                    expand=True))
)

# %%
emp2.shape
# Out:
# (968, 11)

# %%
emp2['DEPARTMENT'].value_counts()
# Out:
# HPD    591
# HFD    377
# Name: DEPARTMENT, dtype: int64

# %%
emp2['RACE'].value_counts()
# Out:
# White                        478
# Hispanic/Latino              250
# Black or African American    240
# Name: RACE, dtype: int64

# %%
common_depts = (emp
    .groupby('DEPARTMENT') 
    .filter(lambda group: len(group) > 50)
)

# %%
fig, ax = plt.subplots(figsize=(8, 6))   
sns.violinplot(x='YEARS_EXPERIENCE', y='GENDER',
    data=common_depts)
# fig.savefig('c13-vio1.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# can use catplot to do viloin plot for combinations of department and race

# %%
grid = sns.catplot(x='YEARS_EXPERIENCE', y='GENDER',
                      col='RACE', row='DEPARTMENT',
                      height=3, aspect=2,
                      data=emp2, kind='violin')
# grid.fig.savefig('c13-vio2.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Uncovering Simpson's Paradox in the diamonds dataset with seaborn

# %% [markdown]
# ### How to do it...

# %%
dia = pd.read_csv('data/diamonds.csv')
dia
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
cut_cats = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_cats = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_cats = ['I1', 'SI2', 'SI1', 'VS2',
                'VS1', 'VVS2', 'VVS1', 'IF']

# applying ordering and putting columns into categories
# creating categorical columns
# nb seaborn uses categroy orders for plots)
dia2 = (dia
    .assign(cut=pd.Categorical(dia['cut'], 
                 categories=cut_cats,
                 ordered=True),
            color=pd.Categorical(dia['color'], 
                 categories=color_cats,
                 ordered=True),
            clarity=pd.Categorical(dia['clarity'], 
                 categories=clarity_cats,
                 ordered=True))
)

# %%
dia2
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
### Barplots of price based on colour, cut and clarity

import seaborn as sns
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14,4))
sns.barplot(x='color', y='price', data=dia2, ax=ax1)
sns.barplot(x='cut', y='price', data=dia2, ax=ax2)
sns.barplot(x='clarity', y='price', data=dia2, ax=ax3)
fig.suptitle('Price Decreasing with Increasing Quality?')
# fig.savefig('c13-bar4.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Price Decreasing with Increasing Quality?')

# %% [markdown]
# Above suggested decreasing trend for color and price. The highest quality cuts and clarity levels also have low prices which doesn't make sense.
#
# Plot barplots of price and color but each clarity level will be plotted

# %%
grid = sns.catplot(x='color', y='price', col='clarity',
    col_wrap=4, data=dia2, kind='bar')
# grid.fig.savefig('c13-bar5.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# Above is better as although price appears to decrease as quality of color increases, doesn not happen with clarity.
#
# Make more plots with size fo diamond to be considered as well

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14,4))
sns.barplot(x='color', y='carat', data=dia2, ax=ax1)
sns.barplot(x='cut', y='carat', data=dia2, ax=ax2)
sns.barplot(x='clarity', y='carat', data=dia2, ax=ax3)
fig.suptitle('Diamond size decreases with quality')
# fig.savefig('c13-bar6.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 0.98, 'Diamond size decreases with quality')

# %% [markdown]
# So above shows higher quality diamonds appear to be smaller in size which makes sense.
#
# Now plot so that we have five different lines for each carat value.
#
# The plot should show higher quality diamonds do in fact cost more money based on size
#
# (plotting mean price per diamond size per group)

# %%
dia2 = (dia2
    .assign(carat_category=pd.qcut(dia2.carat, 5))
)

# %%
import numpy as np
from matplotlib.cm import Greys
greys = Greys(np.arange(50,250,40))
grid = sns.catplot(x='clarity', y='price', data=dia2,
   hue='carat_category', col='color',
   col_wrap=4, kind='point', palette=greys)
grid.fig.suptitle('Diamond price by size, color and clarity',
   y=1.02, size=20)
# grid.fig.savefig('c13-bar7.png', dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 1.02, 'Diamond price by size, color and clarity')

# %% [markdown]
# ### How it works...

# %% [markdown]
# ### There's more...

# %%
g = sns.PairGrid(dia2, height=5,
    x_vars=["color", "cut", "clarity"],
    y_vars=["price"])
g.map(sns.barplot)
g.fig.suptitle('Replication of Step 3 with PairGrid', y=1.02)
# g.fig.savefig('c13-bar8.png', dpi=300, bbox_inches='tight')
